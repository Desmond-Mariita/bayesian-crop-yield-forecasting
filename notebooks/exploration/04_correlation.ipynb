# %% [markdown]
# # Correlation Analysis
#
# **Week 5** - BayesRisk Project
#
# **Author:** Desmond Momanyi Mariita
# **Date:** 2026-01-09
#
# ---

# %%
# Standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Project imports
import sys
sys.path.insert(0, '../src')

# Display settings
pd.set_option('display.max_columns', 100)
# %matplotlib inline

# %% [markdown]
# ## 1. Objectives
#
# - [ ] Objective 1
# - [ ] Objective 2
# - [ ] Objective 3

# %% [markdown]
# ## 2. Implementation

# %%
# Your code here

# %% [markdown]
# ## 3. Results & Analysis

# %% [markdown]
# ## 4. Conclusions
